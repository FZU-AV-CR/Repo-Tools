# %%
from pprint import pprint
from nrp_invenio_client import NRPInvenioClient

# %%
# nrp add alias https://repo.du.cesnet.cz repo --default
# paste token when prompted, link doesnt work

# %%
client = NRPInvenioClient.from_config()

# %%
client = NRPInvenioClient(
    server_url     = "https://workflow-repo.test.du.cesnet.cz",
    token          = "lIkrvBJuZPiV6xxqTynrLU6RsRChXSihKxqLUgz7K9uqUpGOYDBrSg8hEXhL",
    verify         = "/path/to/cert.pem",   # True by default, might be False to disable SSL verification
    retry_count    = 10,                    # idempotent requests will be retried 10 times
    retry_interval = 10,                    # retry interval in seconds if server is busy.
                                            # Exponential backoff is used from retry_interval - 10 * retry_interval
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client = NRPInvenioClient(
#       2     server_url     = "https://workflow-repo.test.du.cesnet.cz",
#       3     token          = "lIkrvBJuZPiV6xxqTynrLU6RsRChXSihKxqLUgz7K9uqUpGOYDBrSg8hEXhL",
#       4     verify         = "/path/to/cert.pem",   # True by default, might be False to disable SSL verification
#       5     retry_count    = 10,                    # idempotent requests will be retried 10 times
#       6     retry_interval = 10,                    # retry interval in seconds if server is busy.
#       7                                             # Exponential backoff is used from retry_interval - 10 * retry_interval
#       8 )
#
# ...

# %%
# load minimal record
import json
with open("minimal_record.json") as f:
    metadata = json.load(f)

# %%
rec = client.records.create("datasets", metadata)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rec = client.records.create("datasets", metadata)
#
# File ~\anaconda3\envs\test\Lib\site-packages\nrp_invenio_client\records.py:280, in NRPRecordsApi.create(self, model, metadata)
#     271 def create(self, model, metadata) -> NRPRecord:
#     272     """
#     273     Creates a new record in the repository
#     274
#    (...)    277     :return:            The created record
#     278     """
#     279     response = self._api.post(
# --> 280         self._api.info.get_model(model).links["api"], data=metadata
#     281     )
#     282     return NRPRecord(
#     283         client=self._api, model=model, record_id=response["id"], data=response
#     284     )
#
# KeyError: 'api'
